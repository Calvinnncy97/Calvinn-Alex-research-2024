# %%
import pandas as pd
import duckdb
import plotly.express as px
import numpy as np

# %%
JSONLINE_OUTPUT = '/home/alextay96/Desktop/workspace/Calvinn-Alex-research-2024/data/owid/silver/owid.jsonl'

# %%
conn = duckdb.connect()

# %%
src_dir = "/home/alextay96/Desktop/workspace/Calvinn-Alex-research-2024/data/owid/bronze"
df = conn.execute(
    f'''
    Select * 
    from read_parquet('{src_dir}/*.parquet')
    '''
).df()

# %%
df.drop_duplicates(subset="url", inplace=True)

# %%
df
# Out:
#                                                    url  \
# 0           https://ourworldindata.org/food-insecurity
# 1                   https://ourworldindata.org/funding
# 2          https://ourworldindata.org/tourism-redesign
# 3          https://ourworldindata.org/vegetarian-vegan
# 4     https://ourworldindata.org/scale-for-electricity
# ..                                                 ...
# 335  https://ourworldindata.org/world-population-gr...
# 336  https://ourworldindata.org/spanish-flu-largest...
# 337                    https://ourworldindata.org/faqs
# 338  https://ourworldindata.org/living-planet-index...
# 339         https://ourworldindata.org/better-learning
#
#                                                  title author published_at  \
# 0                                      food-insecurity
# 1                                              funding
# 2                                     tourism-redesign
# 3                                     vegetarian-vegan
# ...

# %%
df["num_tokens"].sum() /1e6
# Out:
# 1.00488

# %%
df.iloc[np.random.randint(0, len(df))]["content"].split("\n")
# Out:
# ['What does a famine declaration declare?by Joe HasellMarch 12, 2018In recent years, specific criteria have been agreed upon by the international humanitarian community for determining if a food crisis should be considered a famine. But given the range and complexity of food emergencies, the way in which famines, or potential famines, are discussed can still be quite unclear.Here I look at two potentially confusing recent examples and, by considering in more detail how famines are classified, I try to clarify what’s going on.Famine in South Sudan in 2017In February 2017, parts of South Sudan were officially declared by the UN as being in famine – the first such declaration since 2011. By May the famine had apparently receded, thanks to an effective aid response that averted large-scale loss of life. And yet, the crisis was far from over. Indeed the overall food security situation in the country had, in fact, ‘further deteriorated’\xa0over the same period, according to official report
# ...

# %%
jsonl_string = df.to_json(orient='records', lines=True)

with open(JSONLINE_OUTPUT, 'w') as file:
    file.write(jsonl_string)

# %%
df_2 = conn.execute(
    f'''
    Select * 
    from read_json_auto('{JSONLINE_OUTPUT}')
    '''
).df()
df_2
# Out:
#                                                    url  \
# 0           https://ourworldindata.org/food-insecurity
# 1                   https://ourworldindata.org/funding
# 2          https://ourworldindata.org/tourism-redesign
# 3          https://ourworldindata.org/vegetarian-vegan
# 4     https://ourworldindata.org/scale-for-electricity
# ..                                                 ...
# 335  https://ourworldindata.org/world-population-gr...
# 336  https://ourworldindata.org/spanish-flu-largest...
# 337                    https://ourworldindata.org/faqs
# 338  https://ourworldindata.org/living-planet-index...
# 339         https://ourworldindata.org/better-learning
#
#                                                  title author published_at  \
# 0                                      food-insecurity
# 1                                              funding
# 2                                     tourism-redesign
# 3                                     vegetarian-vegan
# ...
